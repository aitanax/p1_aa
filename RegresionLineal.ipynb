# %% [markdown]
# # Regresion Lineal Entrenamiento

# %%
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn import metrics
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
# Para ignorar los warnings
from warnings import simplefilter
from sklearn.exceptions import ConvergenceWarning
simplefilter("ignore", category=ConvergenceWarning)

# %% [markdown]
# Como siempre, realizamos los cambios necesarios para poder trabajar con los datos que nos interesan:

# %%
wind_ava = pd.read_csv('wind_ava.csv.gz', compression="gzip", sep=",")

sotavento_columns = [col for col in wind_ava.columns if ".13" in col]
sotavento_columns.insert(0, "datetime")
sotavento_columns.append("energy")
wind_ava_sotavento = wind_ava[sotavento_columns]

wind_ava_sotavento = wind_ava_sotavento.rename(columns = {
    "energy": "Energy", 
    "datetime": "Datetime", 
    "p54.162.13": "Vertical integral of temperature", 
    "p55.162.13": "Vertical integral of water vapour", 
    "cape.13": "Convective available potential energy", 
    "p59.162.13": "Vertical integral of divergence of kinetic energy", 
    "lai_lv.13": "Leaf area index, low vegetation", 
    "lai_hv.13": "Leaf area index, high vegetation", 
    "u10n.13": "Neutral wind at 10 m u-component", 
    "v10n.13": "Neutral wind at 10 m v-component", 
    "sp.13": "Surface pressure",
    "stl1.13": "Soil temperature level 1",
    "u10.13": "10 metre U wind component",
    "v10.13": "10 metre V wind component",
    "t2m.13": "2 metre temperature", 
    "stl2.13": "Soil temperature level 2", 
    "stl3.13": "Soil temperature level 3", 
    "iews.13": "Instantaneous eastward turbulent surface stress",
    "inss.13": "Instantaneous northward turbulent surface", 
    "stl4.13": "Soil temperature level 4", 
    "fsr.13": "Forecast surface roughness", 
    "flsr.13": "Forecast logarithm of surface roughness for heat",
    "u100.13": "100 metre U wind component",
    "v100.13": "100 metre V wind component", })

wind_ava_sotavento["Datetime"] = pd.to_datetime(wind_ava_sotavento["Datetime"])
wind_ava_sotavento.dtypes
# Out:
# Datetime                                             datetime64[ns]
# Vertical integral of temperature                            float64
# Vertical integral of water vapour                           float64
# Convective available potential energy                       float64
# Vertical integral of divergence of kinetic energy           float64
# Leaf area index, low vegetation                             float64
# Leaf area index, high vegetation                            float64
# Neutral wind at 10 m u-component                            float64
# Neutral wind at 10 m v-component                            float64
# Surface pressure                                            float64
# Soil temperature level 1                                    float64
# 10 metre U wind component                                   float64
# 10 metre V wind component                                   float64
# 2 metre temperature                                         float64
# Soil temperature level 2                                    float64
# Soil temperature level 3                                    float64
# Instantaneous eastward turbulent surface stress             float64
# Instantaneous northward turbulent surface                   float64
# Soil temperature level 4                                    float64
# Forecast surface roughness                                  float64
# Forecast logarithm of surface roughness for heat            float64
# 100 metre U wind component                                  float64
# 100 metre V wind component                                  float64
# Energy                                                      float64
# dtype: object

# %%
duplicate_rows = wind_ava_sotavento[wind_ava_sotavento.duplicated()]
print("Número de filas duplicadas: ", duplicate_rows.shape)
null_rows = wind_ava_sotavento[wind_ava_sotavento.isnull().any(axis=1)]
print("Número de filas nulas: ", null_rows.shape)
# Out:
# Número de filas duplicadas:  (0, 24)
# Número de filas nulas:  (0, 24)

# %% [markdown]
# Definimos el train y test:

# %%
import copy

# Dividir la columna 'Datetime' en dos nuevas columnas: 'fecha' y 'año'
wind_ava_sotavento['Month'] = wind_ava_sotavento['Datetime'].dt.month
wind_ava_sotavento['Year'] = wind_ava_sotavento['Datetime'].dt.year

# Eliminar la columna 'Datetime'
wind_ava_sotavento.drop(columns=['Datetime'], inplace=True)
# Ordenar el DataFrame wind_ava_sotavento por 'Datetime'
wind_ava_sotavento.sort_values(by=['Year', 'Month'], inplace=True)
# Crear una copia profunda del DataFrame wind_ava_sotavento
dataset_1 = copy.deepcopy(wind_ava_sotavento)
# Eliminar la columna 'Energy' de dataset_1
del dataset_1['Energy']
# Crear una copia profunda del DataFrame wind_ava_sotavento
dataset_3 = copy.deepcopy(wind_ava_sotavento)
dataset_2 = dataset_3["Energy"]
dataset_1.info()
dataset_2.info()

x_train, x_test, y_train, y_test = train_test_split(dataset_1, dataset_2, test_size=0.33, random_state=42)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4748 entries, 0 to 4747
# Data columns (total 24 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Vertical integral of temperature                   4748 non-null   float64
#  1   Vertical integral of water vapour                  4748 non-null   float64
#  2   Convective available potential energy              4748 non-null   float64
#  3   Vertical integral of divergence of kinetic energy  4748 non-null   float64
#  4   Leaf area index, low vegetation                    4748 non-null   float64
#  5   Leaf area index, high vegetation                   4748 non-null   float64
#  6   Neutral wind at 10 m u-component                   4748 non-null   float64
#  7   Neutral wind at 10 m v-component                   4748 non-null   float64
#  8   Surface pressure                                   4748 non-null   float64
#  9   Soil temperature level 1                           4748 non-null   float64
#  10  10 metre U wind component                          4748 non-null   float64
#  11  10 metre V wind component                          4748 non-null   float64
#  12  2 metre temperature                                4748 non-null   float64
#  13  Soil temperature level 2                           4748 non-null   float64
#  14  Soil temperature level 3                           4748 non-null   float64
#  15  Instantaneous eastward turbulent surface stress    4748 non-null   float64
#  16  Instantaneous northward turbulent surface          4748 non-null   float64
#  17  Soil temperature level 4                           4748 non-null   float64
#  18  Forecast surface roughness                         4748 non-null   float64
#  19  Forecast logarithm of surface roughness for heat   4748 non-null   float64
#  20  100 metre U wind component                         4748 non-null   float64
#  21  100 metre V wind component                         4748 non-null   float64
#  22  Month                                              4748 non-null   int32
#  23  Year                                               4748 non-null   int32
# dtypes: float64(22), int32(2)
# memory usage: 853.3 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 4748 entries, 0 to 4747
# Series name: Energy
# Non-Null Count  Dtype
# --------------  -----
# 4748 non-null   float64
# dtypes: float64(1)
# memory usage: 37.2 KB

# %% [markdown]
# # Evaluación con hiperparametros por omisión

# %%
# Creamos el modelo de regresión lineal
t_inicio = time.time() # Guardamos el tiempo inicial
LR = LinearRegression()
LR.fit(x_train, y_train)  # Se entrena el modelo
accuracy_train_og = LR.score(x_test, y_test)  # Se obtiene el resultado de aciertos
t_fin = time.time() # Guardamos el tiempo final
print('El modelo de regresión lineal con hiperparámetros por omisión ha obtenido una media de resultado de {:.2f}'.format(accuracy_train_og))
# Miramos sus errores
prediction = LR.predict(x_test)
error_rmse_og = sqrt(mean_squared_error(y_test, prediction))
error_mae_og = mean_absolute_error(y_test, prediction)
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_og, error_mae_og))
t_og = t_fin - t_inicio
print('El tiempo de ejecucion ha sido de {}'.format(t_og))
# Out:
# El modelo de regresión lineal con hiperparámetros por omisión ha obtenido una media de resultado de 0.34
# Como errores:
# 	RMSE	= 541.5647062294927
# 	MAE	= 420.53952472369485
# El tiempo de ejecucion ha sido de 0.01052546501159668

# %% [markdown]
# # Hiperparametros

# %%
params = {'fit_intercept': [True, False],
          'positive': [True, False]}
# Creamos el modelo de regresión lineal con reducción Ridge
t_inicio = time.time() # Guardamos el tiempo inicial
LR = LinearRegression()
np.random.seed(42)  # Para la toma de decisión entre varios puntos
cv = TimeSeriesSplit(n_splits=3, test_size=(365*2))

LR_cv = GridSearchCV(LR, params, cv=cv)
LR_cv.fit(x_train, y_train)
accuracy_train_lrcv = LR_cv.score(x_test, y_test)  # Se obtiene el resultado de aciertos
t_fin = time.time() # Guardamos el tiempo final
print('El modelo de regresión lineal con regulación Ridge (fit_intercept = {} ; positive = {}) ha obtenido una media de resultado de {:.12f}'.format(LR_cv.best_params_['fit_intercept'], LR_cv.best_params_['positive'], accuracy_train_lrcv))
# Miramos sus errores
prediction = LR_cv.predict(x_test)
error_rmse_lrcv = sqrt(mean_squared_error(y_test, prediction))
error_mae_lrcv = mean_absolute_error(y_test, prediction)
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_lrcv, error_mae_lrcv))
t_lrcv = t_fin - t_inicio
print('El tiempo de ejecucion ha sido de {}'.format(t_lrcv))
# Out:
# El modelo de regresión lineal con regulación Ridge (fit_intercept = True ; positive = False) ha obtenido una media de resultado de 0.335192380817
# Como errores:
# 	RMSE	= 541.5647062294927
# 	MAE	= 420.53952472369485
# El tiempo de ejecucion ha sido de 0.07566952705383301
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_nnls.py:135: LinAlgWarning: Ill-conditioned matrix (rcond=2.47406e-17): result may not be accurate.
#   s[P] = solve(AtA[P_ind[:, None], P_ind[None, :]], Atb[P],
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_nnls.py:135: LinAlgWarning: Ill-conditioned matrix (rcond=2.64537e-17): result may not be accurate.
#   s[P] = solve(AtA[P_ind[:, None], P_ind[None, :]], Atb[P],
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_nnls.py:135: LinAlgWarning: Ill-conditioned matrix (rcond=2.46685e-17): result may not be accurate.
#   s[P] = solve(AtA[P_ind[:, None], P_ind[None, :]], Atb[P],
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_nnls.py:135: LinAlgWarning: Ill-conditioned matrix (rcond=1.18399e-17): result may not be accurate.
#   s[P] = solve(AtA[P_ind[:, None], P_ind[None, :]], Atb[P],
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_nnls.py:135: LinAlgWarning: Ill-conditioned matrix (rcond=1.25188e-17): result may not be accurate.
#   s[P] = solve(AtA[P_ind[:, None], P_ind[None, :]], Atb[P],
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_nnls.py:135: LinAlgWarning: Ill-conditioned matrix (rcond=3.0987e-17): result may not be accurate.
#   s[P] = solve(AtA[P_ind[:, None], P_ind[None, :]], Atb[P],
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_nnls.py:135: LinAlgWarning: Ill-conditioned matrix (rcond=1.18456e-17): result may not be accurate.
#   s[P] = solve(AtA[P_ind[:, None], P_ind[None, :]], Atb[P],

# %%
dt_lrcv = pd.DataFrame(LR_cv.cv_results_)
dt_lrcv.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_548cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_548cd_level0_col0" class="col_heading level0 col0" >mean_fit_time</th>
#       <th id="T_548cd_level0_col1" class="col_heading level0 col1" >std_fit_time</th>
#       <th id="T_548cd_level0_col2" class="col_heading level0 col2" >mean_score_time</th>
#       <th id="T_548cd_level0_col3" class="col_heading level0 col3" >std_score_time</th>
#       <th id="T_548cd_level0_col4" class="col_heading level0 col4" >param_fit_intercept</th>
#       <th id="T_548cd_level0_col5" class="col_heading level0 col5" >param_positive</th>
#       <th id="T_548cd_level0_col6" class="col_heading level0 col6" >params</th>
#       <th id="T_548cd_level0_col7" class="col_heading level0 col7" >split0_test_score</th>
#       <th id="T_548cd_level0_col8" class="col_heading level0 col8" >split1_test_score</th>
#       <th id="T_548cd_level0_col9" class="col_heading level0 col9" >split2_test_score</th>
#       <th id="T_548cd_level0_col10" class="col_heading level0 col10" >mean_test_score</th>
#       <th id="T_548cd_level0_col11" class="col_heading level0 col11" >std_test_score</th>
#       <th id="T_548cd_level0_col12" class="col_heading level0 col12" >rank_test_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_548cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_548cd_row0_col0" class="data row0 col0" >0.004243</td>
#       <td id="T_548cd_row0_col1" class="data row0 col1" >0.000717</td>
#       <td id="T_548cd_row0_col2" class="data row0 col2" >0.002505</td>
#       <td id="T_548cd_row0_col3" class="data row0 col3" >0.000710</td>
#       <td id="T_548cd_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_548cd_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_548cd_row0_col6" class="data row0 col6" >{'fit_intercept': True, 'positive': True}</td>
#       <td id="T_548cd_row0_col7" class="data row0 col7" >0.218422</td>
#       <td id="T_548cd_row0_col8" class="data row0 col8" >0.216470</td>
#       <td id="T_548cd_row0_col9" class="data row0 col9" >0.266613</td>
#       <td id="T_548cd_row0_col10" class="data row0 col10" >0.233835</td>
#       <td id="T_548cd_row0_col11" class="data row0 col11" >0.023191</td>
#       <td id="T_548cd_row0_col12" class="data row0 col12" >3</td>
#     </tr>
#     <tr>
#       <th id="T_548cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_548cd_row1_col0" class="data row1 col0" >0.004551</td>
#       <td id="T_548cd_row1_col1" class="data row1 col1" >0.000778</td>
#       <td id="T_548cd_row1_col2" class="data row1 col2" >0.001761</td>
#       <td id="T_548cd_row1_col3" class="data row1 col3" >0.000169</td>
#       <td id="T_548cd_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_548cd_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_548cd_row1_col6" class="data row1 col6" >{'fit_intercept': True, 'positive': False}</td>
#       <td id="T_548cd_row1_col7" class="data row1 col7" >0.310270</td>
#       <td id="T_548cd_row1_col8" class="data row1 col8" >0.248734</td>
#       <td id="T_548cd_row1_col9" class="data row1 col9" >0.370170</td>
#       <td id="T_548cd_row1_col10" class="data row1 col10" >0.309725</td>
#       <td id="T_548cd_row1_col11" class="data row1 col11" >0.049578</td>
#       <td id="T_548cd_row1_col12" class="data row1 col12" >1</td>
#     </tr>
#     <tr>
#       <th id="T_548cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_548cd_row2_col0" class="data row2 col0" >0.002511</td>
#       <td id="T_548cd_row2_col1" class="data row2 col1" >0.000429</td>
#       <td id="T_548cd_row2_col2" class="data row2 col2" >0.002009</td>
#       <td id="T_548cd_row2_col3" class="data row2 col3" >0.000011</td>
#       <td id="T_548cd_row2_col4" class="data row2 col4" >False</td>
#       <td id="T_548cd_row2_col5" class="data row2 col5" >True</td>
#       <td id="T_548cd_row2_col6" class="data row2 col6" >{'fit_intercept': False, 'positive': True}</td>
#       <td id="T_548cd_row2_col7" class="data row2 col7" >0.211620</td>
#       <td id="T_548cd_row2_col8" class="data row2 col8" >0.218195</td>
#       <td id="T_548cd_row2_col9" class="data row2 col9" >0.268284</td>
#       <td id="T_548cd_row2_col10" class="data row2 col10" >0.232700</td>
#       <td id="T_548cd_row2_col11" class="data row2 col11" >0.025305</td>
#       <td id="T_548cd_row2_col12" class="data row2 col12" >4</td>
#     </tr>
#     <tr>
#       <th id="T_548cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_548cd_row3_col0" class="data row3 col0" >0.003647</td>
#       <td id="T_548cd_row3_col1" class="data row3 col1" >0.000764</td>
#       <td id="T_548cd_row3_col2" class="data row3 col2" >0.001399</td>
#       <td id="T_548cd_row3_col3" class="data row3 col3" >0.000455</td>
#       <td id="T_548cd_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_548cd_row3_col5" class="data row3 col5" >False</td>
#       <td id="T_548cd_row3_col6" class="data row3 col6" >{'fit_intercept': False, 'positive': False}</td>
#       <td id="T_548cd_row3_col7" class="data row3 col7" >0.310973</td>
#       <td id="T_548cd_row3_col8" class="data row3 col8" >0.248696</td>
#       <td id="T_548cd_row3_col9" class="data row3 col9" >0.369228</td>
#       <td id="T_548cd_row3_col10" class="data row3 col10" >0.309632</td>
#       <td id="T_548cd_row3_col11" class="data row3 col11" >0.049216</td>
#       <td id="T_548cd_row3_col12" class="data row3 col12" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Regulacion Ridge

# %%
# Creamos el modelo de regresión lineal con reducción Ridge
t_inicio = time.time() # Guardamos el tiempo inicial
R = Ridge()
R.fit(x_train, y_train)  # Se entrena el modelo
accuracy_train_r = R.score(x_test, y_test)  # Se obtiene el resultado de aciertos
t_fin = time.time() # Guardamos el tiempo final
print('El modelo de regresión lineal con regulación Ridge ha obtenido una media de resultado de {:.2f}'.format(accuracy_train_r))
# Miramos sus errores
prediction = R.predict(x_test)
error_rmse_r = sqrt(mean_squared_error(y_test, prediction))
error_mae_r = mean_absolute_error(y_test, prediction)
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_r, error_mae_r))
t_r = t_fin - t_inicio
print('El tiempo de ejecucion ha sido de {}'.format(t_r))
# Out:
# El modelo de regresión lineal con regulación Ridge ha obtenido una media de resultado de 0.30
# Como errores:
# 	RMSE	= 555.300206774558
# 	MAE	= 432.56248868785514
# El tiempo de ejecucion ha sido de 0.004067659378051758

# %% [markdown]
# Buscamos entonces el alpha óptimo:

# %%
# Creamos 100 ejemplos de alphas que vayan desde 1e-10 hasta 1000
params = {'alpha': np.logspace(-10, 3, 100)}
# Creamos el modelo de regresión lineal con reducción Ridge
t_inicio = time.time() # Guardamos el tiempo inicial
R = Ridge()

cv = TimeSeriesSplit(n_splits=5)

R_cv = GridSearchCV(R, params, cv=cv)
R_cv.fit(x_train, y_train)
accuracy_train_rcv = R_cv.score(x_test, y_test)  # Se obtiene el resultado de aciertos
t_fin = time.time() # Guardamos el tiempo final
print('El modelo de regresión lineal con regulación Ridge (alpha = {}) ha obtenido una media de resultado de {:.2f}'.format(R_cv.best_params_['alpha'], accuracy_train_rcv))
# Miramos sus errores
prediction = R_cv.predict(x_test)
error_rmse_rcv = sqrt(mean_squared_error(y_test, prediction))
error_mae_rcv = mean_absolute_error(y_test, prediction)
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_rcv, error_mae_rcv))
t_rcv = t_fin - t_inicio
print('El tiempo de ejecucion ha sido de {}'.format(t_rcv))
# Out:
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11696e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11696e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11696e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11696e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11696e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11696e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11696e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11696e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11696e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11697e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11697e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11697e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11697e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11697e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11697e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11697e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24324e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99622e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11698e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24325e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99622e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11698e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24325e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99622e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11699e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24325e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16609e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05601e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99622e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11699e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24325e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.1661e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05602e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99622e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.117e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24326e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.1661e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05602e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99622e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11702e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24326e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.1661e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05602e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99622e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11704e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24327e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16611e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05602e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99623e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11706e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24328e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16611e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05603e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99623e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.1171e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.2433e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16612e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05604e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99623e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11715e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24331e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16614e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05604e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99624e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11721e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24334e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16615e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05606e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99625e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.1173e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24338e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16618e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05607e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99627e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11742e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24342e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16621e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.0561e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99628e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11758e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24349e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16625e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05613e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99631e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11779e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24357e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16631e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05617e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99634e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11809e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24369e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16638e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05622e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99639e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11848e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24385e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16649e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.0563e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99645e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11902e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24407e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16663e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.0564e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99653e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.11974e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24436e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16682e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05654e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99664e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.12072e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24475e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16708e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05673e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.99679e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.12205e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24528e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.16743e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.05698e-18): result may not be accurate.
# ...
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=6.91802e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=6.49205e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.75607e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.05415e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=8.65259e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.57549e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.02007e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.17896e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.2412e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=9.88391e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=8.46515e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.73428e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.76004e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.49431e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.15502e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=9.669e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=8.70059e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=3.54608e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.83684e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.3805e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.1298e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.0008e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.60974e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.3004e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.68566e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.35025e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.17769e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=6.04948e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.92784e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.09862e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.64852e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.41704e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.99885e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=3.77721e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.65753e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.05215e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.74091e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.06391e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.92692e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=3.41403e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.59839e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.17917e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=6.48324e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.43806e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=3.33767e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.77226e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=8.58986e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.82408e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.33826e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=3.57495e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.69957e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.6923e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=4.66126e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.02386e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.52469e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=6.13165e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.00051e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=8.12085e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.08133e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# El modelo de regresión lineal con regulación Ridge (alpha = 0.002257019719633926) ha obtenido una media de resultado de 0.34
# Como errores:
# 	RMSE	= 541.6114823221181
# 	MAE	= 420.59782605318964
# El tiempo de ejecucion ha sido de 2.119220495223999
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24178e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
dt_grid = pd.DataFrame(R_cv.cv_results_)
dt_grid.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b9aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b9aa_level0_col0" class="col_heading level0 col0" >mean_fit_time</th>
#       <th id="T_6b9aa_level0_col1" class="col_heading level0 col1" >std_fit_time</th>
#       <th id="T_6b9aa_level0_col2" class="col_heading level0 col2" >mean_score_time</th>
#       <th id="T_6b9aa_level0_col3" class="col_heading level0 col3" >std_score_time</th>
#       <th id="T_6b9aa_level0_col4" class="col_heading level0 col4" >param_alpha</th>
#       <th id="T_6b9aa_level0_col5" class="col_heading level0 col5" >params</th>
#       <th id="T_6b9aa_level0_col6" class="col_heading level0 col6" >split0_test_score</th>
#       <th id="T_6b9aa_level0_col7" class="col_heading level0 col7" >split1_test_score</th>
#       <th id="T_6b9aa_level0_col8" class="col_heading level0 col8" >split2_test_score</th>
#       <th id="T_6b9aa_level0_col9" class="col_heading level0 col9" >split3_test_score</th>
#       <th id="T_6b9aa_level0_col10" class="col_heading level0 col10" >split4_test_score</th>
#       <th id="T_6b9aa_level0_col11" class="col_heading level0 col11" >mean_test_score</th>
#       <th id="T_6b9aa_level0_col12" class="col_heading level0 col12" >std_test_score</th>
#       <th id="T_6b9aa_level0_col13" class="col_heading level0 col13" >rank_test_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b9aa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b9aa_row0_col0" class="data row0 col0" >0.002139</td>
#       <td id="T_6b9aa_row0_col1" class="data row0 col1" >0.000785</td>
#       <td id="T_6b9aa_row0_col2" class="data row0 col2" >0.001742</td>
#       <td id="T_6b9aa_row0_col3" class="data row0 col3" >0.000752</td>
#       <td id="T_6b9aa_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_6b9aa_row0_col5" class="data row0 col5" >{'alpha': 1e-10}</td>
#       <td id="T_6b9aa_row0_col6" class="data row0 col6" >0.318441</td>
#       <td id="T_6b9aa_row0_col7" class="data row0 col7" >0.317182</td>
#       <td id="T_6b9aa_row0_col8" class="data row0 col8" >0.292701</td>
#       <td id="T_6b9aa_row0_col9" class="data row0 col9" >0.307692</td>
#       <td id="T_6b9aa_row0_col10" class="data row0 col10" >0.352909</td>
#       <td id="T_6b9aa_row0_col11" class="data row0 col11" >0.317785</td>
#       <td id="T_6b9aa_row0_col12" class="data row0 col12" >0.019827</td>
#       <td id="T_6b9aa_row0_col13" class="data row0 col13" >60</td>
#     </tr>
#     <tr>
#       <th id="T_6b9aa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6b9aa_row1_col0" class="data row1 col0" >0.002408</td>
#       <td id="T_6b9aa_row1_col1" class="data row1 col1" >0.000796</td>
#       <td id="T_6b9aa_row1_col2" class="data row1 col2" >0.001602</td>
#       <td id="T_6b9aa_row1_col3" class="data row1 col3" >0.000354</td>
#       <td id="T_6b9aa_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_6b9aa_row1_col5" class="data row1 col5" >{'alpha': 1.3530477745798075e-10}</td>
#       <td id="T_6b9aa_row1_col6" class="data row1 col6" >0.318441</td>
#       <td id="T_6b9aa_row1_col7" class="data row1 col7" >0.317182</td>
#       <td id="T_6b9aa_row1_col8" class="data row1 col8" >0.292701</td>
#       <td id="T_6b9aa_row1_col9" class="data row1 col9" >0.307692</td>
#       <td id="T_6b9aa_row1_col10" class="data row1 col10" >0.352909</td>
#       <td id="T_6b9aa_row1_col11" class="data row1 col11" >0.317785</td>
#       <td id="T_6b9aa_row1_col12" class="data row1 col12" >0.019827</td>
#       <td id="T_6b9aa_row1_col13" class="data row1 col13" >59</td>
#     </tr>
#     <tr>
#       <th id="T_6b9aa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6b9aa_row2_col0" class="data row2 col0" >0.002692</td>
#       <td id="T_6b9aa_row2_col1" class="data row2 col1" >0.000994</td>
#       <td id="T_6b9aa_row2_col2" class="data row2 col2" >0.001300</td>
#       <td id="T_6b9aa_row2_col3" class="data row2 col3" >0.000366</td>
#       <td id="T_6b9aa_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_6b9aa_row2_col5" class="data row2 col5" >{'alpha': 1.8307382802953697e-10}</td>
#       <td id="T_6b9aa_row2_col6" class="data row2 col6" >0.318441</td>
#       <td id="T_6b9aa_row2_col7" class="data row2 col7" >0.317182</td>
#       <td id="T_6b9aa_row2_col8" class="data row2 col8" >0.292701</td>
#       <td id="T_6b9aa_row2_col9" class="data row2 col9" >0.307692</td>
#       <td id="T_6b9aa_row2_col10" class="data row2 col10" >0.352909</td>
#       <td id="T_6b9aa_row2_col11" class="data row2 col11" >0.317785</td>
#       <td id="T_6b9aa_row2_col12" class="data row2 col12" >0.019827</td>
#       <td id="T_6b9aa_row2_col13" class="data row2 col13" >58</td>
#     </tr>
#     <tr>
#       <th id="T_6b9aa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6b9aa_row3_col0" class="data row3 col0" >0.002020</td>
#       <td id="T_6b9aa_row3_col1" class="data row3 col1" >0.000062</td>
#       <td id="T_6b9aa_row3_col2" class="data row3 col2" >0.001616</td>
#       <td id="T_6b9aa_row3_col3" class="data row3 col3" >0.000589</td>
#       <td id="T_6b9aa_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_6b9aa_row3_col5" class="data row3 col5" >{'alpha': 2.477076355991714e-10}</td>
#       <td id="T_6b9aa_row3_col6" class="data row3 col6" >0.318441</td>
#       <td id="T_6b9aa_row3_col7" class="data row3 col7" >0.317182</td>
#       <td id="T_6b9aa_row3_col8" class="data row3 col8" >0.292701</td>
#       <td id="T_6b9aa_row3_col9" class="data row3 col9" >0.307692</td>
#       <td id="T_6b9aa_row3_col10" class="data row3 col10" >0.352909</td>
#       <td id="T_6b9aa_row3_col11" class="data row3 col11" >0.317785</td>
#       <td id="T_6b9aa_row3_col12" class="data row3 col12" >0.019827</td>
#       <td id="T_6b9aa_row3_col13" class="data row3 col13" >57</td>
#     </tr>
#     <tr>
#       <th id="T_6b9aa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6b9aa_row4_col0" class="data row4 col0" >0.012694</td>
#       <td id="T_6b9aa_row4_col1" class="data row4 col1" >0.019567</td>
#       <td id="T_6b9aa_row4_col2" class="data row4 col2" >0.002209</td>
#       <td id="T_6b9aa_row4_col3" class="data row4 col3" >0.000860</td>
#       <td id="T_6b9aa_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_6b9aa_row4_col5" class="data row4 col5" >{'alpha': 3.351602650938848e-10}</td>
#       <td id="T_6b9aa_row4_col6" class="data row4 col6" >0.318441</td>
#       <td id="T_6b9aa_row4_col7" class="data row4 col7" >0.317182</td>
#       <td id="T_6b9aa_row4_col8" class="data row4 col8" >0.292701</td>
#       <td id="T_6b9aa_row4_col9" class="data row4 col9" >0.307692</td>
#       <td id="T_6b9aa_row4_col10" class="data row4 col10" >0.352909</td>
#       <td id="T_6b9aa_row4_col11" class="data row4 col11" >0.317785</td>
#       <td id="T_6b9aa_row4_col12" class="data row4 col12" >0.019827</td>
#       <td id="T_6b9aa_row4_col13" class="data row4 col13" >56</td>
#     </tr>
#     <tr>
#       <th id="T_6b9aa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6b9aa_row5_col0" class="data row5 col0" >0.002381</td>
#       <td id="T_6b9aa_row5_col1" class="data row5 col1" >0.000519</td>
#       <td id="T_6b9aa_row5_col2" class="data row5 col2" >0.001678</td>
#       <td id="T_6b9aa_row5_col3" class="data row5 col3" >0.000528</td>
#       <td id="T_6b9aa_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_6b9aa_row5_col5" class="data row5 col5" >{'alpha': 4.5348785081285916e-10}</td>
#       <td id="T_6b9aa_row5_col6" class="data row5 col6" >0.318441</td>
#       <td id="T_6b9aa_row5_col7" class="data row5 col7" >0.317182</td>
#       <td id="T_6b9aa_row5_col8" class="data row5 col8" >0.292701</td>
#       <td id="T_6b9aa_row5_col9" class="data row5 col9" >0.307692</td>
#       <td id="T_6b9aa_row5_col10" class="data row5 col10" >0.352909</td>
#       <td id="T_6b9aa_row5_col11" class="data row5 col11" >0.317785</td>
#       <td id="T_6b9aa_row5_col12" class="data row5 col12" >0.019827</td>
#       <td id="

# %% [markdown]
# Nueva evaluacion, ahora con el alpha generado esperando una mejora:

# %%
# Creamos el modelo de regresión lineal con reducción Ridge
t_inicio = time.time() # Guardamos el tiempo inicial
R = Ridge(alpha = 0.002257019719633926)
R.fit(x_train, y_train)  # Se entrena el modelo
accuracy_train_r = R.score(x_test, y_test)  # Se obtiene el resultado de aciertos
t_fin = time.time() # Guardamos el tiempo final
print('El modelo de regresión lineal con regulación Ridge ha obtenido una media de resultado de {:.2f}'.format(accuracy_train_r))
# Miramos sus errores
prediction = R.predict(x_test)
error_rmse_r = sqrt(mean_squared_error(y_test, prediction))
error_mae_r = mean_absolute_error(y_test, prediction)
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_r, error_mae_r))
t_r = t_fin - t_inicio
print('El tiempo de ejecucion ha sido de {}'.format(t_r))
# Out:
# El modelo de regresión lineal con regulación Ridge ha obtenido una media de resultado de 0.34
# Como errores:
# 	RMSE	= 541.6114823221181
# 	MAE	= 420.59782605318964
# El tiempo de ejecucion ha sido de 0.037305593490600586
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24178e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %% [markdown]
# Se observa la mejora, pasamos de un 30% a un 34%

# %% [markdown]
# # Regulación Lasso

# %%
# Creamos el modelo de regresión lineal con reducción Lasso
t_inicio = time.time() # Guardamos el tiempo inicial
L = Lasso()
L.fit(x_train, y_train)  # Se entrena el modelo
accuracy_train_l = L.score(x_test, y_test)  # Se obtiene el resultado de aciertos
t_fin = time.time() # Guardamos el tiempo final
print('El modelo de regresión lineal con regulación Lasso ha obtenido una media de resultado de {:.2f}'.format(accuracy_train_l))
# Miramos sus errores
prediction = L.predict(x_test)
error_rmse_l = sqrt(mean_squared_error(y_test, prediction))
error_mae_l = mean_absolute_error(y_test, prediction)
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_l, error_mae_l))
t_l = t_fin - t_inicio
print('El tiempo de ejecucion ha sido de {}'.format(t_l))
# Out:
# El modelo de regresión lineal con regulación Lasso ha obtenido una media de resultado de 0.30
# Como errores:
# 	RMSE	= 557.0228247499601
# 	MAE	= 434.6129491061683
# El tiempo de ejecucion ha sido de 0.06743979454040527

# %%
# Creamos 100 ejemplos de alphas que vayan desde 1e-10 hasta 1000
params = {'alpha': np.logspace(-10, 3, 100)}
# Creamos el modelo de regresión lineal
t_inicio = time.time() # Guardamos el tiempo inicial
L = Lasso()
np.random.seed(42)  # Para la toma de decisión entre varios puntos
cv = TimeSeriesSplit(n_splits=5)

L_cv = GridSearchCV(L, params, cv=cv)
L_cv.fit(x_train, y_train)  # Se entrena el modelo
accuracy_train_lcv = L_cv.score(x_test, y_test)  # Se obtiene el resultado de aciertos
t_fin = time.time() # Guardamos el tiempo final
print('El modelo de regresión lineal con regulación Lasso (alpha = {}) ha obtenido una media de resultado de {:.2f}'.format(L_cv.best_params_['alpha'], accuracy_train_lcv))
# Miramos sus errores
prediction = L_cv.predict(x_test)
error_rmse_lcv = sqrt(mean_squared_error(y_test, prediction))
error_mae_lcv = mean_absolute_error(y_test, prediction)
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_lcv, error_mae_lcv))
t_lcv = t_fin - t_inicio
print('El tiempo de ejecucion ha sido de {}'.format(t_lcv))
# Out:
# El modelo de regresión lineal con regulación Lasso (alpha = 0.08497534359086473) ha obtenido una media de resultado de 0.33
# Como errores:
# 	RMSE	= 541.941966811329
# 	MAE	= 421.31687943791763
# El tiempo de ejecucion ha sido de 16.377796411514282

# %%
dt_grid = pd.DataFrame(L_cv.cv_results_)
dt_grid.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_b9b65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9b65_level0_col0" class="col_heading level0 col0" >mean_fit_time</th>
#       <th id="T_b9b65_level0_col1" class="col_heading level0 col1" >std_fit_time</th>
#       <th id="T_b9b65_level0_col2" class="col_heading level0 col2" >mean_score_time</th>
#       <th id="T_b9b65_level0_col3" class="col_heading level0 col3" >std_score_time</th>
#       <th id="T_b9b65_level0_col4" class="col_heading level0 col4" >param_alpha</th>
#       <th id="T_b9b65_level0_col5" class="col_heading level0 col5" >params</th>
#       <th id="T_b9b65_level0_col6" class="col_heading level0 col6" >split0_test_score</th>
#       <th id="T_b9b65_level0_col7" class="col_heading level0 col7" >split1_test_score</th>
#       <th id="T_b9b65_level0_col8" class="col_heading level0 col8" >split2_test_score</th>
#       <th id="T_b9b65_level0_col9" class="col_heading level0 col9" >split3_test_score</th>
#       <th id="T_b9b65_level0_col10" class="col_heading level0 col10" >split4_test_score</th>
#       <th id="T_b9b65_level0_col11" class="col_heading level0 col11" >mean_test_score</th>
#       <th id="T_b9b65_level0_col12" class="col_heading level0 col12" >std_test_score</th>
#       <th id="T_b9b65_level0_col13" class="col_heading level0 col13" >rank_test_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9b65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9b65_row0_col0" class="data row0 col0" >0.037856</td>
#       <td id="T_b9b65_row0_col1" class="data row0 col1" >0.015041</td>
#       <td id="T_b9b65_row0_col2" class="data row0 col2" >0.001584</td>
#       <td id="T_b9b65_row0_col3" class="data row0 col3" >0.000449</td>
#       <td id="T_b9b65_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_b9b65_row0_col5" class="data row0 col5" >{'alpha': 1e-10}</td>
#       <td id="T_b9b65_row0_col6" class="data row0 col6" >0.319878</td>
#       <td id="T_b9b65_row0_col7" class="data row0 col7" >0.316220</td>
#       <td id="T_b9b65_row0_col8" class="data row0 col8" >0.293102</td>
#       <td id="T_b9b65_row0_col9" class="data row0 col9" >0.307941</td>
#       <td id="T_b9b65_row0_col10" class="data row0 col10" >0.353088</td>
#       <td id="T_b9b65_row0_col11" class="data row0 col11" >0.318046</td>
#       <td id="T_b9b65_row0_col12" class="data row0 col12" >0.019794</td>
#       <td id="T_b9b65_row0_col13" class="data row0 col13" >71</td>
#     </tr>
#     <tr>
#       <th id="T_b9b65_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9b65_row1_col0" class="data row1 col0" >0.034146</td>
#       <td id="T_b9b65_row1_col1" class="data row1 col1" >0.016871</td>
#       <td id="T_b9b65_row1_col2" class="data row1 col2" >0.001728</td>
#       <td id="T_b9b65_row1_col3" class="data row1 col3" >0.000408</td>
#       <td id="T_b9b65_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_b9b65_row1_col5" class="data row1 col5" >{'alpha': 1.3530477745798075e-10}</td>
#       <td id="T_b9b65_row1_col6" class="data row1 col6" >0.319878</td>
#       <td id="T_b9b65_row1_col7" class="data row1 col7" >0.316220</td>
#       <td id="T_b9b65_row1_col8" class="data row1 col8" >0.293102</td>
#       <td id="T_b9b65_row1_col9" class="data row1 col9" >0.307941</td>
#       <td id="T_b9b65_row1_col10" class="data row1 col10" >0.353088</td>
#       <td id="T_b9b65_row1_col11" class="data row1 col11" >0.318046</td>
#       <td id="T_b9b65_row1_col12" class="data row1 col12" >0.019794</td>
#       <td id="T_b9b65_row1_col13" class="data row1 col13" >70</td>
#     </tr>
#     <tr>
#       <th id="T_b9b65_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9b65_row2_col0" class="data row2 col0" >0.034665</td>
#       <td id="T_b9b65_row2_col1" class="data row2 col1" >0.016348</td>
#       <td id="T_b9b65_row2_col2" class="data row2 col2" >0.001707</td>
#       <td id="T_b9b65_row2_col3" class="data row2 col3" >0.000414</td>
#       <td id="T_b9b65_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_b9b65_row2_col5" class="data row2 col5" >{'alpha': 1.8307382802953697e-10}</td>
#       <td id="T_b9b65_row2_col6" class="data row2 col6" >0.319878</td>
#       <td id="T_b9b65_row2_col7" class="data row2 col7" >0.316220</td>
#       <td id="T_b9b65_row2_col8" class="data row2 col8" >0.293102</td>
#       <td id="T_b9b65_row2_col9" class="data row2 col9" >0.307941</td>
#       <td id="T_b9b65_row2_col10" class="data row2 col10" >0.353088</td>
#       <td id="T_b9b65_row2_col11" class="data row2 col11" >0.318046</td>
#       <td id="T_b9b65_row2_col12" class="data row2 col12" >0.019794</td>
#       <td id="T_b9b65_row2_col13" class="data row2 col13" >69</td>
#     </tr>
#     <tr>
#       <th id="T_b9b65_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9b65_row3_col0" class="data row3 col0" >0.037241</td>
#       <td id="T_b9b65_row3_col1" class="data row3 col1" >0.021210</td>
#       <td id="T_b9b65_row3_col2" class="data row3 col2" >0.001919</td>
#       <td id="T_b9b65_row3_col3" class="data row3 col3" >0.000497</td>
#       <td id="T_b9b65_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_b9b65_row3_col5" class="data row3 col5" >{'alpha': 2.477076355991714e-10}</td>
#       <td id="T_b9b65_row3_col6" class="data row3 col6" >0.319878</td>
#       <td id="T_b9b65_row3_col7" class="data row3 col7" >0.316220</td>
#       <td id="T_b9b65_row3_col8" class="data row3 col8" >0.293102</td>
#       <td id="T_b9b65_row3_col9" class="data row3 col9" >0.307941</td>
#       <td id="T_b9b65_row3_col10" class="data row3 col10" >0.353088</td>
#       <td id="T_b9b65_row3_col11" class="data row3 col11" >0.318046</td>
#       <td id="T_b9b65_row3_col12" class="data row3 col12" >0.019794</td>
#       <td id="T_b9b65_row3_col13" class="data row3 col13" >68</td>
#     </tr>
#     <tr>
#       <th id="T_b9b65_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9b65_row4_col0" class="data row4 col0" >0.037951</td>
#       <td id="T_b9b65_row4_col1" class="data row4 col1" >0.016685</td>
#       <td id="T_b9b65_row4_col2" class="data row4 col2" >0.001909</td>
#       <td id="T_b9b65_row4_col3" class="data row4 col3" >0.000494</td>
#       <td id="T_b9b65_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_b9b65_row4_col5" class="data row4 col5" >{'alpha': 3.351602650938848e-10}</td>
#       <td id="T_b9b65_row4_col6" class="data row4 col6" >0.319878</td>
#       <td id="T_b9b65_row4_col7" class="data row4 col7" >0.316220</td>
#       <td id="T_b9b65_row4_col8" class="data row4 col8" >0.293102</td>
#       <td id="T_b9b65_row4_col9" class="data row4 col9" >0.307941</td>
#       <td id="T_b9b65_row4_col10" class="data row4 col10" >0.353088</td>
#       <td id="T_b9b65_row4_col11" class="data row4 col11" >0.318046</td>
#       <td id="T_b9b65_row4_col12" class="data row4 col12" >0.019794</td>
#       <td id="T_b9b65_row4_col13" class="data row4 col13" >67</td>
#     </tr>
#     <tr>
#       <th id="T_b9b65_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b9b65_row5_col0" class="data row5 col0" >0.036305</td>
#       <td id="T_b9b65_row5_col1" class="data row5 col1" >0.019298</td>
#       <td id="T_b9b65_row5_col2" class="data row5 col2" >0.001617</td>
#       <td id="T_b9b65_row5_col3" class="data row5 col3" >0.000378</td>
#       <td id="T_b9b65_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_b9b65_row5_col5" class="data row5 col5" >{'alpha': 4.5348785081285916e-10}</td>
#       <td id="T_b9b65_row5_col6" class="data row5 col6" >0.319878</td>
#       <td id="T_b9b65_row5_col7" class="data row5 col7" >0.316220</td>
#       <td id="T_b9b65_row5_col8" class="data row5 col8" >0.293102</td>
#       <td id="T_b9b65_row5_col9" class="data row5 col9" >0.307941</td>
#       <td id="T_b9b65_row5_col10" class="data row5 col10" >0.353088</td>
#       <td id="T_b9b65_row5_col11" class="data row5 col11" >0.318046</td>
#       <td id="T_b9b65_row5_col12" class="data row5 col12" >0.019794</td>
#       <td id="

# %% [markdown]
# # Regulacion Elastic net

# %%
# Creamos el modelo de regresión lineal con reducción Elastic net
t_inicio = time.time() # Guardamos el tiempo inicial
EN = ElasticNet()
EN.fit(x_train, y_train)  # Se entrena el modelo
accuracy_train_en = EN.score(x_test, y_test)  # Se obtiene el resultado de aciertos
t_fin = time.time() # Guardamos el tiempo final
print('El modelo de regresión lineal con regulación Elastic net ha obtenido una media de resultado de {:.2f}'.format(accuracy_train_en))
# Miramos sus errores
prediction = EN.predict(x_test)
error_rmse_en = sqrt(mean_squared_error(y_test, prediction))
error_mae_en = mean_absolute_error(y_test, prediction)
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_en, error_mae_en))
t_en = t_fin - t_inicio
print('El tiempo de ejecucion ha sido de {}'.format(t_en))
# Out:
# El modelo de regresión lineal con regulación Elastic net ha obtenido una media de resultado de 0.25
# Como errores:
# 	RMSE	= 574.901142839115
# 	MAE	= 456.3650447244232
# El tiempo de ejecucion ha sido de 0.033965349197387695

# %%
# Creamos 100 ejemplos de alphas que vayan desde 1e-10 hasta 10
params = {'alpha': np.logspace(-10, 3, 100),
          'l1_ratio': np.arange(0, 1, 0.05)}
# Creamos el modelo de regresión lineal con reducción Elastic net
t_inicio = time.time() # Guardamos el tiempo inicial
EN = ElasticNet()

cv = TimeSeriesSplit(n_splits=5)

EN_cv = GridSearchCV(EN, params, cv=cv)
EN_cv.fit(x_train, y_train)  # Se entrena el modelo
accuracy_train_encv = EN_cv.score(x_test, y_test)  # Se obtiene el resultado de aciertos
t_fin = time.time() # Guardamos el tiempo final
print('El modelo de regresión lineal con regulación Elastic net (alpha = {} ; l1_ratio = {}) ha obtenido una media de resultado de {:.2f}'.format(EN_cv.best_params_['alpha'], EN_cv.best_params_['l1_ratio'], accuracy_train_encv))
# Miramos sus errores
prediction = EN_cv.predict(x_test)
error_rmse_encv = sqrt(mean_squared_error(y_test, prediction))
error_mae_encv = mean_absolute_error(y_test, prediction)
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_encv, error_mae_encv))
t_encv = t_fin - t_inicio
print('El tiempo de ejecucion ha sido de {}'.format(t_encv))
# Out:
# El modelo de regresión lineal con regulación Elastic net (alpha = 7.220809018385471e-06 ; l1_ratio = 0.65) ha obtenido una media de resultado de 0.33
# Como errores:
# 	RMSE	= 541.879579155234
# 	MAE	= 420.9355947919723
# El tiempo de ejecucion ha sido de 308.89621686935425

# %%
# Creamos el modelo de regresión lineal con reducción Elastic net
t_inicio = time.time() # Guardamos el tiempo inicial
EN = ElasticNet(alpha=7.220809018385471e-06, l1_ratio=0.65)
np.random.seed(42)  # Para la toma de decisión entre varios puntos

EN.fit(x_train, y_train)  # Se entrena el modelo
accuracy_train_encv = EN.score(x_test, y_test)  # Se obtiene el resultado de aciertos
t_fin = time.time() # Guardamos el tiempo final
print('El modelo de regresión lineal con regulación Elastic net ha obtenido una media de resultado de {:.12f}'.format(accuracy_train_encv))
# Miramos sus errores
prediction = EN.predict(x_test)
error_rmse_encv = sqrt(mean_squared_error(y_test, prediction))
error_mae_encv = mean_absolute_error(y_test, prediction)
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_encv, error_mae_encv))
t_encv = t_fin - t_inicio
print('El tiempo de ejecucion ha sido de {}'.format(t_encv))
# Out:
# El modelo de regresión lineal con regulación Elastic net ha obtenido una media de resultado de 0.334419100094
# Como errores:
# 	RMSE	= 541.879579155234
# 	MAE	= 420.9355947919723
# El tiempo de ejecucion ha sido de 0.10938096046447754

# %% [markdown]
# # Conclusion

# %%
# Creamos el modelo de regresión lineal con reducción Ridge
t_inicio = time.time() # Guardamos el tiempo inicial
R = Ridge(alpha = 0.002257019719633926)
R.fit(x_train, y_train)  # Se entrena el modelo
accuracy_train_final = R.score(x_test, y_test)  # Se obtiene el resultado de aciertos
t_fin = time.time() # Guardamos el tiempo final
print('El modelo de regresión lineal con regulación Ridge ha obtenido una media de resultado de {:.2f}'.format(accuracy_train_r))
# Miramos sus errores
prediction = R.predict(x_test)
error_rmse_final = sqrt(mean_squared_error(y_test, prediction))
error_mae_final = mean_absolute_error(y_test, prediction)
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_r, error_mae_r))
t_final = t_fin - t_inicio
print('El tiempo de ejecucion ha sido de {}'.format(t_r))
# Out:
# El modelo de regresión lineal con regulación Ridge ha obtenido una media de resultado de 0.34
# Como errores:
# 	RMSE	= 541.6114823221181
# 	MAE	= 420.59782605318964
# El tiempo de ejecucion ha sido de 0.037305593490600586
# c:\Users\aitan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=5.24178e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
print('El modelo de regresión lineal con hiperparámetros por omisión ha obtenido una media de resultado de {:.12f}'.format(accuracy_train_og))
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_og, error_mae_og))
print('El tiempo de ejecucion con hiperparámetros por omisión ha sido de {}'.format(t_og))
print("")
print('El modelo de regresión lineal con regulación Ridge ha obtenido una media de resultado de {:.12f}'.format(accuracy_train_final))
print('Como errores:\n\tRMSE\t= {}\n\tMAE\t= {}'.format(error_rmse_final, error_mae_final))
print('El tiempo de ejecucion con hiperparámetros por omisión ha sido de {}'.format(t_final))
# Out:
# El modelo de regresión lineal con hiperparámetros por omisión ha obtenido una media de resultado de 0.335192380817
# Como errores:
# 	RMSE	= 541.5647062294927
# 	MAE	= 420.53952472369485
# El tiempo de ejecucion con hiperparámetros por omisión ha sido de 0.01052546501159668
#
# El modelo de regresión lineal con regulación Ridge ha obtenido una media de resultado de 0.335077534168
# Como errores:
# 	RMSE	= 541.6114823221181
# 	MAE	= 420.59782605318964
# El tiempo de ejecucion con hiperparámetros por omisión ha sido de 0.011455059051513672
